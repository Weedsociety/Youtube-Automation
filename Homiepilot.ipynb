# %% [markdown]
# <a href="https://colab.research.google.com/github/Weedsociety/Youtube-Automation/blob/main/Homiepilot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai -q

# %%
import openai
import pandas as pd
import numpy as np
from getpass import getpass

openai.api_key = getpass()
# Out:
# ··········

# %%
df = pd.read_csv('test.csv')
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-d90d954dcb54> in <cell line: 1>()
# ----> 1 df = pd.read_csv('test.csv')
#       2 print(df)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
from openai.embeddings_utils import get_embedding

df['embedding'] = df['strain'].apply(lambda x: get_embedding(x, engine='text-embedding-ada-002'))
df.to_csv('word_embeddings.csv')

# %%
df = pd.read_csv('word_embeddings.csv')
df['embedding'] = df['embedding'].apply(eval).apply(np.array)
df
# Out:
#     Unnamed: 0                                             strain  \
# 0            0  We're still gathering information about the 24...
# 1            1  We're still gathering information about the 22...
# 2            2  We're still gathering information about the 20...
# 3            3  We're still gathering information about the 11...
# 4            4  13 Dawgs by Canadian team Delta 9 Biotech is a...
# 5            5  24K Gold, also known as 24K or Kosher Tangie, ...
# 6            6  We're still gathering information about the 10...
# 7            7  We're still gathering information about the 33...
# 8            8  22 OG is an indica-dominant strain by 22Red, a...
# 9            9  We're still gathering information about the 33...
# 10          10  303 OG Kush is a strain with various sources o...
# 11          11  10k Jack is a cultivar of unconfirmed origins ...
# 12          12  We're still gathering information about the 2 ...
# ...

# %%
search_term = input('Enter a Strain:')
# Out:
# Enter a Strain: 5 Alive by Cannarado

# %%
# semantic search
search_term_vector = get_embedding(search_term, engine="text-embedding-ada-002")
search_term_vector
# Out:
# [-0.01463254727423191,
#  -0.009415486827492714,
#  -0.007178619969636202,
#  -0.023043164983391762,
#  -0.011012264527380466,
#  -0.005771114956587553,
#  -0.007213033270090818,
#  -0.039864398539066315,
#  -0.007075380068272352,
#  -0.00355145544745028,
#  0.016697347164154053,
#  0.024419697001576424,
#  -0.027792204171419144,
#  -0.014962914399802685,
#  -0.012058430351316929,
#  0.021941937506198883,
#  0.016945121809840202,
#  -0.0353768989443779,
#  0.00975961983203888,
#  -0.0016673257341608405,
#  0.0011261760955676436,
#  -0.003064506920054555,
#  -0.007770529482513666,
#  -0.007330038584768772,
#  -0.004157130140811205,
#  -0.0007132161990739405,
#  -0.019078748300671577,
#  -0.020744353532791138,
#  0.018555665388703346,
#  -0.013524437323212624,
#  0.04870174080133438,
#  -0.020579170435667038,
#  0.005151675082743168,
#  -0.018610727041959763,
#  -0.012705400586128235,
#  -0.010853963904082775,
#  -0.016229325905442238,
#  -0.012567747384309769,
# ...

# %%
from openai.embeddings_utils import cosine_similarity

df["similarities"] = df['embedding'].apply(lambda x: cosine_similarity(x, search_term_vector))

df
# Out:
#     Unnamed: 0                                             strain  \
# 0            0  We're still gathering information about the 24...
# 1            1  We're still gathering information about the 22...
# 2            2  We're still gathering information about the 20...
# 3            3  We're still gathering information about the 11...
# 4            4  13 Dawgs by Canadian team Delta 9 Biotech is a...
# 5            5  24K Gold, also known as 24K or Kosher Tangie, ...
# 6            6  We're still gathering information about the 10...
# 7            7  We're still gathering information about the 33...
# 8            8  22 OG is an indica-dominant strain by 22Red, a...
# 9            9  We're still gathering information about the 33...
# 10          10  303 OG Kush is a strain with various sources o...
# 11          11  10k Jack is a cultivar of unconfirmed origins ...
# 12          12  We're still gathering information about the 2 ...
# ...

# %%
df.sort_values("similarities", ascending=False).head(20)
# Out:
#     Unnamed: 0                                             strain  \
# 44          44  5 Alive by Cannarado is a three-way combinatio...
# 40          40  We're still gathering information about the 5 ...
# 52          52  Elemental Seeds created 5th Element (also know...
# 38          38  Grassroots Cannabis created 9a95 as a combinat...
# 7            7  We're still gathering information about the 33...
# 39          39  We're still gathering information about the 5G...
# 41          41  Mycotek Seeds created 3 Gorillas by combining ...
# 48          48  We're still gathering information about the 45...
# 43          43  We're still gathering information about the 5L...
# 34          34  9A95 Kunduz is a sativa-dominant cultivar crea...
# 22          22  90s Dutch is a sativa-dominant cultivar create...
# 21          21  We're still gathering information about the 7 ...
# 42          42  We're still gathering information about the 41...
# ...
